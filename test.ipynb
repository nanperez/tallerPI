# %% [markdown]
# <a href="https://colab.research.google.com/github/nanperez/tallerPI/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importamos librerias**

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Cargamos una imagen

# %%
img = cv2.imread("/content/sample_data/hoja.jpg")
plt.imshow(img)
plt.title("Imagen original")
plt.axis("off")
plt.show()
